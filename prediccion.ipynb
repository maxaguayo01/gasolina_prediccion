# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import plotly.graph_objects as go

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense

# %%
df = pd.read_csv('historical_country_mexico_indicator_gasoline_prices_.csv')
df = df[['DateTime', 'Close']]
df['DateTime'] = pd.to_datetime(df['DateTime'])
df = df.set_index('DateTime')
fecha_inicio = '2012-12-01'
df = df[fecha_inicio:]
df.head()
# Out:
#             Close
# DateTime
# 2012-12-31   0.86
# 2013-01-31   0.85
# 2013-02-28   0.87
# 2013-03-31   0.87
# 2013-04-30   0.91

# %%
    # Configurar el renderizador de Plotly para VSCode
    import plotly.io as pio
    pio.renderers.default = "vscode"

# %%
import plotly.graph_objects as go

# Crear la figura
fig = go.Figure()


fig.add_trace(go.Scatter(
    x=df.index,
    y=df['Close'],
    mode='lines',
    name='Precio Histórico',
    line=dict(color='#00CC96', width=2) # Color verde cian
))



# Configuración del diseño (Layout)
fig.update_layout(
    title="Precio de la gasolina en mexico — Histórico",
    xaxis_title="Fecha",
    yaxis_title="Precio (lt/T)",
    template="plotly_dark",      # Fondo oscuro
    hovermode="x unified",       # Muestra el valor al pasar el ratón
    legend=dict(
        orientation="h",         # Leyenda horizontal arriba
        yanchor="bottom",
        y=1.02,
        xanchor="right",
        x=1
    )
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/modelos-no-lineales/gasolina_prediccion/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/Documents/modelos-no-lineales/gasolina_prediccion/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/Documents/modelos-no-lineales/gasolina_prediccion/.venv/lib/python3.12/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'line': {'color': '#00CC96', 'width': 2},
#               'mode': 'lines',
#               'name': 'Precio Histórico',
#               'type': 'scatter',
#               'x': array(['2012-12-31T00:00:00.000000000', '2013-01-31T00:00:00.000000000',
#                           '2013-02-28T00:00:00.000000000', '2013-03-31T00:00:00.000000000',
#                           '2013-04-30T00:00:00.000000000', '2013-05-31T00:00:00.000000000',
#                           '2013-06-30T00:00:00.000000000', '2013-07-31T00:00:00.000000000',
#                           '2013-08-31T00:00:00.000000000', '2013-09-30T00:00:00.000000000',
#                           '2013-10-31T00:00:00.000000000', '2013-11-30T00:00:00.000000000',
#                           '2013-12-31T00:00:00.000000000', '2014-01-31T00:00:00.000000000',
#                           '2014-02-28T00:00:00.000000000', '2014-03-31T00:00:00.000000000',
#                           '2014-04-30T00:00:00.000000000', '2014-05-31T00:00:00.000000000',
#                           '2014-06-30T00:00:00.000000000', '2014-07-31T00:00:00.000000000',
#                           '2014-08-31T00:00:00.000000000', '2014-09-30T00:00:00.000000000',
#                           '2014-10-31T00:00:00.000000000', '2014-11-30T00:00:00.000000000',
#                           '2014-12-31T00:00:00.000000000', '2015-01-31T00:00:00.000000000',
#                           '2015-02-28T00:00:00.000000000', '2015-03-31T00:00:00.000000000',
#                           '2015-04-30T00:00:00.000000000', '2015-05-31T00:00:00.000000000',
#                           '2015-06-30T00:00:00.000000000', '2015-07-31T00:00:00.000000000',
#                           '2015-08-31T00:00:00.000000000', '2015-09-30T00:00:00.000000000',
#                           '2015-10-31T00:00:00.000000000', '2015-11-30T00:00:00.000000000',
#                           '2015-12-31T00:00:00.000000000', '2016-01-31T00:00:00.000000000',
#                           '2016-02-29T00:00:00.000000000', '2016-03-31T00:00:00.000000000',
#                           '2016-04-30T00:00:00.000000000', '2016-05-31T00:00:00.000000000',
#                           '2016-06-30T00:00:00.000000000', '2016-07-31T00:00:00.000000000',
#                           '2016-08-31T00:00:00.000000000', '2016-09-30T00:00:00.000000000',
#                           '2016-10-31T00:00:00.000000000', '2016-11-30T00:00:00.000000000',
#                           '2016-12-31T00:00:00.000000000', '2017-01-01T00:00:00.000000000',
#                           '2017-02-28T00:00:00.000000000', '2017-03-31T00:00:00.000000000',
#                           '2017-04-30T00:00:00.000000000', '2017-05-31T00:00:00.000000000',
00:00:00.000000000'], dtype='datetime64[ns]'),
#               'y': {'bdata': ('hetRuB6F6z8zMzMzMzPrP9ejcD0K1+' ... 'L1KPQ/exSuR+F69D8pXI/C9Sj0Pw=='),
#                     'dtype': 'f8'}}],
#     'layout': {'hovermode': 'x unified',
#                'legend': {'orientation': 'h', 'x': 1, 'xanchor': 'right', 'y': 1.02, 'yanchor': 'bottom'},
#                'template': '...',
#                'title': {'text': 'Precio de la gasolina en mexico — Histórico'},
#                'xaxis': {'title': {'text': 'Fecha'}},
#                'yaxis': {'title': {'text': 'Precio (lt/T)'}}}
# })

# %%
# Convertir a numpy para el modelo
serie = df['Close'].values
# Definir tamaño de ventana
window_size = 12

def crear_ventanas(datos, window_size):
    X, y = [], []
    for i in range(len(datos) - window_size):
        X.append(datos[i : i + window_size])
        y.append(datos[i + window_size])
    return np.array(X), np.array(y)

# %%
porcentaje_train = 0.8
n_train = int(len(serie) * porcentaje_train)

# Ajustamos tamaño a (n,1) para que el minmax scaler funcione correctamente
serie = serie.reshape(-1, 1)
serie_train = serie[:n_train] # Solo el pasado
serie_test  = serie[n_train:] # Solo el futuro

# %%
#  Ajustar el MinMaxScaler SOLO con el entrenamiento
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(serie_train)

# Transformar train y test con el scaler ya entrenado
serie_train_scaled = scaler.transform(serie_train) 
serie_test_scaled  = scaler.transform(serie_test)

# %%
X_train, y_train = crear_ventanas(serie_train_scaled, window_size)
X_test,  y_test  = crear_ventanas(serie_test_scaled,  window_size)

# %%
model = Sequential([
    Input(shape=(window_size, 1)),
    LSTM(units=10),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 10)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 491 (1.92 KB)
#  Trainable params: 491 (1.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
hist = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.1851 - val_loss: 0.4001
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1428 - val_loss: 0.3176
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1059 - val_loss: 0.2431
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0749 - val_loss: 0.1777
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0502 - val_loss: 0.1245
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0338 - val_loss: 0.0839
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0241 - val_loss: 0.0551
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0204 - val_loss: 0.0368
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0204 - val_loss: 0.0269
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0215 - val_loss: 0.0235
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0220 - val_loss: 0.0238
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0216 - val_loss: 0.0266
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0207 - val_loss: 0.0318
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0200 - val_loss: 0.0383
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - val_loss: 0.0438
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0199 - val_loss: 0.0498
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0201 - val_loss: 0.0506
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0200 - val_loss: 0.0478
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0197 - val_loss: 0.0448
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - val_loss: 0.0417
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0193 - val_loss: 0.0385
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0194 - val_loss: 0.0339
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0195 - val_loss: 0.0314
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0195 - val_loss: 0.0322
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0193 - val_loss: 0.0338
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0192 - val_loss: 0.0344
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190 - val_loss: 0.0368
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0191 - val_loss: 0.0397
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190 - val_loss: 0.0382
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190 - val_loss: 0.0370
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0189 - val_loss: 0.0379
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0188 - val_loss: 0.0405
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189 - val_loss: 0.0423
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0190 - val_loss: 0.0431
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0191 - val_loss: 0.0428
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189 - val_loss: 0.0391
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0186 - val_loss: 0.0346
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0185 - val_loss: 0.0277
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0187 - val_loss: 0.0235
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0192 - val_loss: 0.0238
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0190 - val_loss: 0.0266
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0186 - val_loss: 0.0293
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0184 - val_loss: 0.0312
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0183 - val_loss: 0.0312
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0182 - val_loss: 0.0303
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0182 - val_loss: 0.0300
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0181 - val_loss: 0.0305
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0181 - val_loss: 0.0296
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0181 - val_loss: 0.0300
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0181 - val_loss: 0.0340

# %%
# Predicciones en test pero resultado esta en escala {0,1}
y_pred_scaled = model.predict(X_test)

# Convertir a columna (N,1)
y_test_scaled_2d = y_test.reshape(-1,1)
y_pred_scaled_2d = y_pred_scaled.reshape(-1,1)

# Inverse transform
y_test_real = scaler.inverse_transform(y_test_scaled_2d).flatten()
y_pred_real = scaler.inverse_transform(y_pred_scaled_2d).flatten()
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x314b1ff60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
# Ajustar índices de tiempo para alinearlos con la serie original
idx_inicio_test = n_train + window_size
idx_start_test = n_train + window_size
idx_end_test = idx_start_test + len(y_test_real)

fechas_test = df['Close'].index[idx_start_test : idx_end_test]

# %%
# Graficar resultados en escala real

fig = go.Figure()

# Serie completa real
fig.add_trace(go.Scatter(
    x=df.index,
    y=df['Close'].values,
    mode="lines",
    name="Serie real completa"
))

# Valores reales del test
fig.add_trace(go.Scatter(
    x=fechas_test,
    y=y_test_real,
    mode="lines",
    name="Valor real (test)"
))

# Predicciones ya invertidas
fig.add_trace(go.Scatter(
    x=fechas_test,
    y=y_pred_real,
    mode="lines",
    name="Predicción LSTM (test)",
    line=dict(dash="dot")
))

fig.update_layout(
    title="Predicción sobre el conjunto de prueba (escala real)",
    xaxis_title="Fecha",
    yaxis_title="Precio de Acción"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/modelos-no-lineales/gasolina_prediccion/.venv/lib/python3.12/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/Documents/modelos-no-lineales/gasolina_prediccion/.venv/lib/python3.12/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/Documents/modelos-no-lineales/gasolina_prediccion/.venv/lib/python3.12/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'mode': 'lines',
#               'name': 'Serie real completa',
#               'type': 'scatter',
#               'x': array(['2012-12-31T00:00:00.000000000', '2013-01-31T00:00:00.000000000',
#                           '2013-02-28T00:00:00.000000000', '2013-03-31T00:00:00.000000000',
#                           '2013-04-30T00:00:00.000000000', '2013-05-31T00:00:00.000000000',
#                           '2013-06-30T00:00:00.000000000', '2013-07-31T00:00:00.000000000',
#                           '2013-08-31T00:00:00.000000000', '2013-09-30T00:00:00.000000000',
#                           '2013-10-31T00:00:00.000000000', '2013-11-30T00:00:00.000000000',
#                           '2013-12-31T00:00:00.000000000', '2014-01-31T00:00:00.000000000',
#                           '2014-02-28T00:00:00.000000000', '2014-03-31T00:00:00.000000000',
#                           '2014-04-30T00:00:00.000000000', '2014-05-31T00:00:00.000000000',
#                           '2014-06-30T00:00:00.000000000', '2014-07-31T00:00:00.000000000',
#                           '2014-08-31T00:00:00.000000000', '2014-09-30T00:00:00.000000000',
#                           '2014-10-31T00:00:00.000000000', '2014-11-30T00:00:00.000000000',
#                           '2014-12-31T00:00:00.000000000', '2015-01-31T00:00:00.000000000',
#                           '2015-02-28T00:00:00.000000000', '2015-03-31T00:00:00.000000000',
#                           '2015-04-30T00:00:00.000000000', '2015-05-31T00:00:00.000000000',
#                           '2015-06-30T00:00:00.000000000', '2015-07-31T00:00:00.000000000',
#                           '2015-08-31T00:00:00.000000000', '2015-09-30T00:00:00.000000000',
#                           '2015-10-31T00:00:00.000000000', '2015-11-30T00:00:00.000000000',
#                           '2015-12-31T00:00:00.000000000', '2016-01-31T00:00:00.000000000',
#                           '2016-02-29T00:00:00.000000000', '2016-03-31T00:00:00.000000000',
#                           '2016-04-30T00:00:00.000000000', '2016-05-31T00:00:00.000000000',
#                           '2016-06-30T00:00:00.000000000', '2016-07-31T00:00:00.000000000',
#                           '2016-08-31T00:00:00.000000000', '2016-09-30T00:00:00.000000000',
#                           '2016-10-31T00:00:00.000000000', '2016-11-30T00:00:00.000000000',
#                           '2024-08-31T00:00:00.000000000', '2024-09-30T00:00:00.000000000',
#                           '2024-10-31T00:00:00.000000000', '2024-11-30T00:00:00.000000000',
#                           '2024-12-31T00:00:00.000000000', '2025-01-31T00:00:00.000000000',
#                           '2025-02-28T00:00:00.000000000', '2025-03-31T00:00:00.000000000',
#                           '2025-04-30T00:00:00.000000000', '2025-05-31T00:00:00.000000000',
#                           '2025-06-30T00:00:00.000000000', '2025-07-31T00:00:00.000000000',
#                           '2025-08-31T00:00:00.000000000', '2025-09-30T00:00:00.000000000',
#                           '2025-10-31T00:00:00.000000000'], dtype='datetime64[ns]'),
#               'y': {'bdata': ('hetRuB6F6z8zMzMzMzPrP9ejcD0K1+' ... 'L1KPQ/exSuR+F69D8pXI/C9Sj0Pw=='),
#                     'dtype': 'f8'}},
#              {'mode': 'lines',
#               'name': 'Valor real (test)',
#               'type': 'scatter',
#               'x': array(['2024-04-30T00:00:00.000000000', '2024-05-31T00:00:00.000000000',
#                           '2024-06-30T00:00:00.000000000', '2024-07-31T00:00:00.000000000',
#                           '2024-08-31T00:00:00.000000000', '2024-09-30T00:00:00.000000000',
#                           '2024-10-31T00:00:00.000000000', '2024-11-30T00:00:00.000000000',
#                           '2024-12-31T00:00:00.000000000', '2025-01-31T00:00:00.000000000',
#                           '2025-02-28T00:00:00.000000000', '2025-03-31T00:00:00.000000000',
#                           '2025-04-30T00:00:00.000000000', '2025-05-31T00:00:00.000000000',
#                           '2025-06-30T00:00:00.000000000', '2025-07-31T00:00:00.000000000',
#                           '2025-08-31T00:00:00.000000000', '2025-09-30T00:00:00.000000000',
#                           '2025-10-31T00:00:00.000000000'], dtype='datetime64[ns]'),
#               'y': {'bdata': ('w/UoXI/C9T9xPQrXo3D1P83MzMzMzP' ... '/C9Sj0P3sUrkfhevQ/KVyPwvUo9D8='),
#                     'dtype': 'f8'}},
#              {'line': {'dash': 'dot'},
#               'mode': 'lines',
#               'name': 'Predicción LSTM (test)',
#               'type': 'scatter',
#               'x': array(['2024-04-30T00:00:00.000000000', '2024-05-31T00:00:00.000000000',
#                           '2024-06-30T00:00:00.000000000', '2024-07-31T00:00:00.000000000',
#                           '2024-08-31T00:00:00.000000000', '2024-09-30T00:00:00.000000000',
#                           '2024-10-31T00:00:00.000000000', '2024-11-30T00:00:00.000000000',
#                           '2024-12-31T00:00:00.000000000', '2025-01-31T00:00:00.000000000',
#                           '2025-02-28T00:00:00.000000000', '2025-03-31T00:00:00.000000000',
#                           '2025-04-30T00:00:00.000000000', '2025-05-31T00:00:00.000000000',
#                           '2025-06-30T00:00:00.000000000', '2025-07-31T00:00:00.000000000',
#                           '2025-08-31T00:00:00.000000000', '2025-09-30T00:00:00.000000000',
#                           '2025-10-31T00:00:00.000000000'], dtype='datetime64[ns]'),
#               'y': {'bdata': ('+leOP6PFjj9W/o4/lc+OP1afjj8NMI' ... '8TnIg/r9iIPzj9iD+SQok/UsWJPw=='),
#                     'dtype': 'f4'}}],
#     'layout': {'template': '...',
#                'title': {'text': 'Predicción sobre el conjunto de prueba (escala real)'},
#                'xaxis': {'title': {'text': 'Fecha'}},
#                'yaxis': {'title': {'text': 'Precio de Acción'}}}
# })
